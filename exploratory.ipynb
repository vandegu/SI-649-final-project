# %% [markdown]
# # Initial data exploration: data cleaning

# %%
import numpy as np
import pandas as pd

# %%
def basic_analysis(DF):
    print(DF.shape)
    basic_info = pd.DataFrame(DF.isna().sum(),columns=['# NULL'])
    basic_info['Type'] = DF.dtypes.values
    basic_info['Unique'] = DF.nunique()
    return basic_info

# %%
steam = pd.read_csv('data/steam.csv')

# %% [markdown]
# ### Start by cleaning the steam dataset

# %%
bi = basic_analysis(steam)
bi
# Out:
# (27075, 18)
#                   # NULL     Type  Unique
# appid                  0    int64   27075
# name                   0   object   27033
# release_date           0   object    2619
# english                0    int64       2
# developer              0   object   17113
# publisher              0   object   14354
# platforms              0   object       7
# required_age           0    int64       6
# categories             0   object    3333
# genres                 0   object    1552
# steamspy_tags          0   object    6423
# achievements           0    int64     410
# positive_ratings       0    int64    2800
# negative_ratings       0    int64    1492
# average_playtime       0    int64    1345
# median_playtime        0    int64    1312
# owners                 0   object      13
# price                  0  float64     282

# %%
steam.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price
# 0   7.19
# 1   3.99
# 2   3.99
# 3   3.99
# 4   3.99

# %%
# First make owners an integer
def make_owners_int(x):
    numbers = x.split('-')
    numbers = [int(i) for i in numbers]
    return round((numbers[1]+numbers[0])/2)

steamnew = steam.copy()
steamnew['num_owners'] = steamnew.owners.apply(make_owners_int)

# %%
steamnew.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 2              Multi-player;Valve Anti-Cheat enabled  Action
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action
#
#                   steamspy_tags  achievements  positive_ratings  \
# 0        Action;FPS;Multiplayer             0            124534
# 1        Action;FPS;Multiplayer             0              3318
# 2  FPS;World War II;Multiplayer             0              3416
# 3        Action;FPS;Multiplayer             0              1273
# 4             FPS;Action;Sci-fi             0              5250
#
#    negative_ratings  average_playtime  median_playtime             owners  \
# 0              3339             17612              317  10000000-20000000
# 1               633               277               62   5000000-10000000
# 2               398               187               34   5000000-10000000
# 3               267               258              184   5000000-10000000
# 4               288               624              415   5000000-10000000
#
#    price  num_owners
# 0   7.19    15000000
# 1   3.99     7500000
# 2   3.99     7500000
# 3   3.99     7500000
# 4   3.99     7500000

# %%
# Now, how many unique values in genres?
steam.genres.unique()
# Out:
# array(['Action', 'Action;Free to Play', 'Action;Free to Play;Strategy',
#        ...,
#        'Action;Adventure;Indie;Massively Multiplayer;RPG;Strategy;Early Access',
#        'Action;Adventure;Casual;Free to Play;Indie;RPG;Simulation;Sports;Strategy',
#        'Casual;Free to Play;Massively Multiplayer;RPG;Early Access'],
#       dtype=object)

# %%
steam_wide = steamnew.copy() # Wide format with each game having one row.

# %% [markdown]
# ### Idea: Separate the multiple genres into new rows; one per genre per game. There will be multiple rows per game, but then we can aggregate by genre because each row will only have one genre.

# %%
steamnew.columns
# Out:
# Index(['appid', 'name', 'release_date', 'english', 'developer', 'publisher',
#        'platforms', 'required_age', 'categories', 'genres', 'steamspy_tags',
#        'achievements', 'positive_ratings', 'negative_ratings',
#        'average_playtime', 'median_playtime', 'owners', 'price', 'num_owners'],
#       dtype='object')

# %%
# convert to list
steamnew['genres'] = steamnew['genres'].str.split(';')

# convert list of pd.Series then stack it
steamnew = (steamnew
 .set_index(['appid', 'name', 'release_date', 'english', 'developer', 'publisher',
       'platforms', 'required_age', 'categories', 'steamspy_tags',
       'achievements', 'positive_ratings', 'negative_ratings',
       'average_playtime', 'median_playtime', 'owners', 'price', 'num_owners'])['genres']
 .apply(pd.Series)
 .stack()
 .reset_index()
 .drop('level_18', axis=1)
 .rename(columns={0:'genre'}))

# %%
steamnew
# Out:
#          appid                        name release_date  english  \
# 0           10              Counter-Strike   2000-11-01        1
# 1           20       Team Fortress Classic   1999-04-01        1
# 2           30               Day of Defeat   2003-05-01        1
# 3           40          Deathmatch Classic   2001-06-01        1
# 4           50   Half-Life: Opposing Force   1999-11-01        1
# ...        ...                         ...          ...      ...
# 76457  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 76458  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 76459  1069460                   Rune Lord   2019-04-24        1
# 76460  1069460                   Rune Lord   2019-04-24        1
# 76461  1069460                   Rune Lord   2019-04-24        1
#
#                 developer             publisher          platforms  \
# 0                   Valve                 Valve  windows;mac;linux
# 1                   Valve                 Valve  windows;mac;linux
# 2                   Valve                 Valve  windows;mac;linux
# 3                   Valve                 Valve  windows;mac;linux
# 4        Gearbox Software                 Valve  windows;mac;linux
# ...                   ...                   ...                ...
# 76457  Yustas Game Studio  Alawar Entertainment        windows;mac
# 76458  Yustas Game Studio  Alawar Entertainment        windows;mac
# 76459    Adept Studios GD  Alawar Entertainment        windows;mac
# 76460    Adept Studios GD  Alawar Entertainment        windows;mac
# 76461    Adept Studios GD  Alawar Entertainment        windows;mac
#
#        required_age                                         categories  \
# 0                 0  Multi-player;Online Multi-Player;Local Multi-P...
# 1                 0  Multi-player;Online Multi-Player;Local Multi-P...
# 2                 0              Multi-player;Valve Anti-Cheat enabled
# 3                 0  Multi-player;Online Multi-Player;Local Multi-P...
# 4                 0  Single-player;Multi-player;Valve Anti-Cheat en...
# ...             ...                                                ...
# 76457             0                          Single-player;Steam Cloud
# 76458             0                          Single-player;Steam Cloud
# 76459             0                          Single-player;Steam Cloud
# 76460             0                          Single-player;Steam Cloud
# 76461             0                          Single-player;Steam Cloud
#
#                       steamspy_tags  achievements  positive_ratings  \
# 0            Action;FPS;Multiplayer             0            124534
# 1            Action;FPS;Multiplayer             0              3318
# 2      FPS;World War II;Multiplayer             0              3416
# 3            Action;FPS;Multiplayer             0              1273
# 4                 FPS;Action;Sci-fi             0              5250
# ...                             ...           ...               ...
# 76457        Indie;Casual;Adventure             0                 2
# 76458        Indie;Casual;Adventure             0                 2
# 76459        Indie;Casual;Adventure             0                 4
# 76460        Indie;Casual;Adventure             0                 4
# 76461        Indie;Casual;Adventure             0                 4
#
#        negative_ratings  average_playtime  median_playtime             owners  \
# 0                  3339             17612              317  10000000-20000000
# 1                   633               277               62   5000000-10000000
# 2                   398               187               34   5000000-10000000
# 3                   267               258              184   5000000-10000000
# 4                   288               624              415   5000000-10000000
# ...                 ...               ...              ...                ...
# 76457                 0                 0                0            0-20000
# 76458                 0                 0                0            0-20000
# 76459                 0                 0                0            0-20000
# 76460                 0                 0                0            0-20000
# 76461                 0                 0                0            0-20000
#
#        price  num_owners      genre
# 0       7.19    15000000     Action
# 1       3.99     7500000     Action
# 2       3.99     7500000     Action
# 3       3.99     7500000     Action
# 4       3.99     7500000     Action
# ...      ...         ...        ...
# 76457   5.19       10000     Casual
# 76458   5.19       10000      Indie
# 76459   5.19       10000  Adventure
# 76460   5.19       10000     Casual
# 76461   5.19       10000      Indie
#
# [76462 rows x 19 columns]

# %%
steam_long = steamnew.copy() # Long format is really only long in genre, but still.

# %% [markdown]
# ### Join the description dataset to the wide dataset.

# %%
steamnew = steam_wide.copy()
desc = pd.read_csv('data/steam_description_data.csv')

# %%
bi = basic_analysis(steam_wide)
bi
# Out:
# (27075, 19)
#                   # NULL     Type  Unique
# appid                  0    int64   27075
# name                   0   object   27033
# release_date           0   object    2619
# english                0    int64       2
# developer              0   object   17113
# publisher              0   object   14354
# platforms              0   object       7
# required_age           0    int64       6
# categories             0   object    3333
# genres                 0   object    1552
# steamspy_tags          0   object    6423
# achievements           0    int64     410
# positive_ratings       0    int64    2800
# negative_ratings       0    int64    1492
# average_playtime       0    int64    1345
# median_playtime        0    int64    1312
# owners                 0   object      13
# price                  0  float64     282
# num_owners             0    int64      13

# %%
bi2 = basic_analysis(desc)
bi2
# Out:
# (27334, 4)
#                       # NULL    Type  Unique
# steam_appid                0   int64   27334
# detailed_description       0  object   27315
# about_the_game             0  object   27315
# short_description          0  object   27204

# %%
# Update the column names of desc.
desc = desc.rename(columns={'steam_appid':"appid"})
desc.columns
# Out:
# Index(['appid', 'detailed_description', 'about_the_game', 'short_description'], dtype='object')

# %%
steamnew = steamnew.set_index('appid').join(other=desc.set_index('appid'),on='appid',how='left',rsuffix='_desc')
steamnew.shape
steamnew = steamnew.reset_index()

# %%
steam_wide = steamnew.copy()

# %%
steam_wide.head()
# Out:
#    appid                       name release_date  english         developer  \
# 0     10             Counter-Strike   2000-11-01        1             Valve
# 1     20      Team Fortress Classic   1999-04-01        1             Valve
# 2     30              Day of Defeat   2003-05-01        1             Valve
# 3     40         Deathmatch Classic   2001-06-01        1             Valve
# 4     50  Half-Life: Opposing Force   1999-11-01        1  Gearbox Software
#
#   publisher          platforms  required_age  \
# 0     Valve  windows;mac;linux             0
# 1     Valve  windows;mac;linux             0
# 2     Valve  windows;mac;linux             0
# 3     Valve  windows;mac;linux             0
# 4     Valve  windows;mac;linux             0
#
#                                           categories  genres  ...  \
# 0  Multi-player;Online Multi-Player;Local Multi-P...  Action  ...
# 1  Multi-player;Online Multi-Player;Local Multi-P...  Action  ...
# 2              Multi-player;Valve Anti-Cheat enabled  Action  ...
# 3  Multi-player;Online Multi-Player;Local Multi-P...  Action  ...
# 4  Single-player;Multi-player;Valve Anti-Cheat en...  Action  ...
#
#   positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 0           124534              3339             17612              317
# 1             3318               633               277               62
# 2             3416               398               187               34
# 3             1273               267               258              184
# 4             5250               288               624              415
#
#               owners  price num_owners  \
# 0  10000000-20000000   7.19   15000000
# 1   5000000-10000000   3.99    7500000
# 2   5000000-10000000   3.99    7500000
# 3   5000000-10000000   3.99    7500000
# 4   5000000-10000000   3.99    7500000
#
#                                 detailed_description  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
#                                    short_description
# 0  Play the world's number 1 online action game. ...
# 1  One of the most popular online action games of...
# 2  Enlist in an intense brand of Axis vs. Allied ...
# 3  Enjoy fast-paced multiplayer gaming with Death...
# 4  Return to the Black Mesa Research Facility as ...
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Prep data to rewrite to csv

# %%
steam_long_columns = ['appid', 'name', 'release_date', 'english', 'developer', 'publisher',
       'platforms', 'required_age', 'categories', 'steamspy_tags',
       'achievements', 'positive_ratings', 'negative_ratings',
       'average_playtime', 'median_playtime', 'owners', 'price', 'num_owners',
       'genre']

new_steam_long_columns = ['appid', 'name', 'release_date', 'english', 'developer', 'publisher',
       'achievements', 'positive_ratings', 'negative_ratings',
       'average_playtime', 'median_playtime', 'price', 'num_owners',
       'genre']

steam_wide_columns = ['appid', 'name', 'release_date', 'english', 'developer', 'publisher',
       'platforms', 'required_age', 'categories', 'genres', 'steamspy_tags',
       'achievements', 'positive_ratings', 'negative_ratings',
       'average_playtime', 'median_playtime', 'owners', 'price', 'num_owners',
       'detailed_description', 'about_the_game', 'short_description']

new_steam_wide_columns = ['appid', 'name', 'release_date', 'english', 'developer', 'publisher',
       'achievements', 'positive_ratings', 'negative_ratings',
       'average_playtime', 'median_playtime', 'price', 'num_owners',
       'detailed_description', 'about_the_game', 'short_description']

# %%
steam_long_out = steam_long[new_steam_long_columns].copy()
steam_long_out.tail()
# Out:
#          appid                        name release_date  english  \
# 76457  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 76458  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 76459  1069460                   Rune Lord   2019-04-24        1
# 76460  1069460                   Rune Lord   2019-04-24        1
# 76461  1069460                   Rune Lord   2019-04-24        1
#
#                 developer             publisher  achievements  \
# 76457  Yustas Game Studio  Alawar Entertainment             0
# 76458  Yustas Game Studio  Alawar Entertainment             0
# 76459    Adept Studios GD  Alawar Entertainment             0
# 76460    Adept Studios GD  Alawar Entertainment             0
# 76461    Adept Studios GD  Alawar Entertainment             0
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 76457                 2                 0                 0                0
# 76458                 2                 0                 0                0
# 76459                 4                 0                 0                0
# 76460                 4                 0                 0                0
# 76461                 4                 0                 0                0
#
#        price  num_owners      genre
# 76457   5.19       10000     Casual
# 76458   5.19       10000      Indie
# 76459   5.19       10000  Adventure
# 76460   5.19       10000     Casual
# 76461   5.19       10000      Indie

# %%
steam_wide_out = steam_wide[new_steam_wide_columns].copy()
steam_wide_out.tail()
# Out:
#          appid                        name release_date  english  \
# 27070  1065230             Room of Pandora   2019-04-24        1
# 27071  1065570                   Cyber Gun   2019-04-23        1
# 27072  1065650            Super Star Blast   2019-04-24        1
# 27073  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 27074  1069460                   Rune Lord   2019-04-24        1
#
#                 developer             publisher  achievements  \
# 27070         SHEN JIAWEI           SHEN JIAWEI             7
# 27071      Semyon Maximov      BekkerDev Studio             0
# 27072         EntwicklerX           EntwicklerX            24
# 27073  Yustas Game Studio  Alawar Entertainment             0
# 27074    Adept Studios GD  Alawar Entertainment             0
#
#        positive_ratings  negative_ratings  average_playtime  median_playtime  \
# 27070                 3                 0                 0                0
# 27071                 8                 1                 0                0
# 27072                 0                 1                 0                0
# 27073                 2                 0                 0                0
# 27074                 4                 0                 0                0
#
#        price  num_owners                               detailed_description  \
# 27070   2.09       10000  <img src="https://steamcdn-a.akamaihd.net/stea...
# 27071   1.69       10000  Have you ever been so lonely that no one but y...
# 27072   3.99       10000  <strong>Super Star Blast </strong>is a space b...
# 27073   5.19       10000  Pursue a snow-white deer through an enchanted ...
# 27074   5.19       10000  A portal has opened and dark magic is pouring ...
#
#                                           about_the_game  \
# 27070  <img src="https://steamcdn-a.akamaihd.net/stea...
# 27071  Have you ever been so lonely that no one but y...
# 27072  <strong>Super Star Blast </strong>is a space b...
# 27073  Pursue a snow-white deer through an enchanted ...
# 27074  A portal has opened and dark magic is pouring ...
#
#                                        short_description
# 27070  The Room of Pandora is a third-person interact...
# 27071  Cyber Gun is a hardcore first-person shooter w...
# 27072  Super Star Blast is a space based game with ch...
# 27073  Pursue a snow-white deer through an enchanted ...
# 27074  A portal has opened and dark magic is pouring ...

# %%
steam_long_out.to_csv('steam_long.csv',index=False)
steam_wide_out.to_csv('steam_wide.csv',index=False)
